# %%
# !nvidia-smi
# Out:
# Fri Dec 11 18:09:04 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.45.01    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P8    27W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import gdown
FID = "1yYEV74jG7CbfOE38aZAYZTCuxoBWcJ_R"
URL = "https://drive.google.com/uc?id=" + FID
FNAME = 't2f.zip'
gdown.download(URL, FNAME, quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1yYEV74jG7CbfOE38aZAYZTCuxoBWcJ_R
# To: /content/t2f.zip
# 1.42GB [00:05, 238MB/s]
# 't2f.zip'

# %%
# !unzip -qq t2f.zip
# Out:
# warning [t2f.zip]:  76 extra bytes at beginning or within zipfile
#   (attempting to process anyway)
# error [t2f.zip]:  reported length of central directory is
#   -76 bytes too long (Atari STZip zipfile?  J.H.Holm ZIPSPLIT 1.1
#   zipfile?).  Compensating...
# error:  expected central file header signature not found (file #202622).
#   (please check that you have transferred or created the zipfile in the
#   appropriate BINARY mode and that you have compiled UnZip properly)

# %%
import os
os.rename('/content/text2facegan-master', '/content/text2facegan')

# %%
import gdown
FID = "1K1-ZwLbd80g2d-vXRjA_m2L-knR4R2K8"
URL = "https://drive.google.com/uc?id=" + FID
FNAME = 'faces_5k.hdf5'
gdown.download(URL, FNAME, quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1K1-ZwLbd80g2d-vXRjA_m2L-knR4R2K8
# To: /content/faces_5k.hdf5
# 3.58GB [01:01, 58.7MB/s]
# 'faces_5k.hdf5'

# %%
# !python /content/drive/MyDrive/Deep_Learning/projects/dcgan/train.py
# Out:
# Reading .hdf5 file ...
# cuda:0
# Starting Training Loop...
# [0/150][0/179]	Loss_D: 2.6498	Loss_G: 3.0854
# [0/150][50/179]	Loss_D: 0.3746	Loss_G: 16.6445
# [0/150][100/179]	Loss_D: 0.9545	Loss_G: 18.7148
# [0/150][150/179]	Loss_D: 0.7961	Loss_G: 6.4070
# [1/150][0/179]	Loss_D: 1.2850	Loss_G: 7.2326
# [1/150][50/179]	Loss_D: 0.9384	Loss_G: 3.9176
# [1/150][100/179]	Loss_D: 1.7734	Loss_G: 4.2857
# [1/150][150/179]	Loss_D: 1.7074	Loss_G: 9.5042
# [2/150][0/179]	Loss_D: 0.6590	Loss_G: 4.2011
# [2/150][50/179]	Loss_D: 0.5411	Loss_G: 4.8566
# [2/150][100/179]	Loss_D: 0.6006	Loss_G: 3.2477
# [2/150][150/179]	Loss_D: 0.8370	Loss_G: 5.0543
# [3/150][0/179]	Loss_D: 0.5824	Loss_G: 5.0356
# [3/150][50/179]	Loss_D: 0.2802	Loss_G: 4.5650
# [3/150][100/179]	Loss_D: 0.5228	Loss_G: 4.0265
# [3/150][150/179]	Loss_D: 0.5394	Loss_G: 2.9505
# [4/150][0/179]	Loss_D: 1.4438	Loss_G: 3.1250
# [4/150][50/179]	Loss_D: 0.4002	Loss_G: 3.0792
# [4/150][100/179]	Loss_D: 0.6445	Loss_G: 2.9649
# ...
